# %%
cd "C:\Users\dirty\OneDrive\Documents\Class"
# Out:
# C:\Users\dirty\OneDrive\Documents\Class

# %%
dir
# Out:
# <function dir>

# %%
import pandas as pd

# %%
df = pd.read_csv("covidpolls.csv")

# %%
print(df.head())
# Out:
#       start  end_date         pollster    sponsor  sample_size population  \
# 0  2/2/2020  2/4/2020           YouGov  Economist       1500.0          a
# 1  2/2/2020  2/4/2020           YouGov  Economist        376.0          a
# 2  2/2/2020  2/4/2020           YouGov  Economist        523.0          a
# 3  2/2/2020  2/4/2020           YouGov  Economist        599.0          a
# 4  2/7/2020  2/9/2020  Morning Consult        NaN       2200.0          a
#
#   party subject tracking                                               text  \
# 0   all   Trump    FALSE  Do you approve or disapprove of Donald Trump’s...
# 1     R   Trump    FALSE  Do you approve or disapprove of Donald Trump’s...
# 2     D   Trump    FALSE  Do you approve or disapprove of Donald Trump’s...
# 3     I   Trump    FALSE  Do you approve or disapprove of Donald Trump’s...
# 4   all   Trump    FALSE  Do you approve or disapprove of the job each o...
#
# ...

# %%
print(df.isnull().sum())
# Out:
# start             0
# end_date          0
# pollster          0
# sponsor        1780
# sample_size      31
# population        0
# party             0
# subject           0
# tracking         20
# text              2
# approve           3
# disapprove       15
# url               0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
covidpolls = pd.read_csv("covidpolls.csv")

# %%
covidpolls.head()
# Out:
#       start  end_date         pollster    sponsor  sample_size population  \
# 0  2/2/2020  2/4/2020           YouGov  Economist       1500.0          a
# 1  2/2/2020  2/4/2020           YouGov  Economist        376.0          a
# 2  2/2/2020  2/4/2020           YouGov  Economist        523.0          a
# 3  2/2/2020  2/4/2020           YouGov  Economist        599.0          a
# 4  2/7/2020  2/9/2020  Morning Consult        NaN       2200.0          a
#
#   party subject tracking                                               text  \
# 0   all   Trump    FALSE  Do you approve or disapprove of Donald Trump’s...
# 1     R   Trump    FALSE  Do you approve or disapprove of Donald Trump’s...
# 2     D   Trump    FALSE  Do you approve or disapprove of Donald Trump’s...
# 3     I   Trump    FALSE  Do you approve or disapprove of Donald Trump’s...
# 4   all   Trump    FALSE  Do you approve or disapprove of the job each o...
#
# ...

# %%
grouped = df.groupby(['pollster', 'text'])['approve'].mean()

# %%
print(grouped)
# Out:
# pollster             text
# ABC News             Do you approve or disapprove of the way Trump is handling the coronavirus outbreak?                                       44.588235
# ABC/Washington Post  Do you approve or disapprove of the way Biden is handling the coronavirus pandemic?                                       56.176471
#                      Do you approve or disapprove of the way Biden is handling the coronavirus pandemic?\n                                     48.500000
#                      Do you approve or disapprove of the way Trump has handled the coronavirus outbreak?                                       39.500000
#                      Do you approve or disapprove of the way Trump is handling the coronavirus outbreak?                                       42.000000
#                                                                                                                                                  ...
# ...

# %%
# !pip install pandas matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 4.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.1 MB 5.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 5.9 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.1 MB 6.2 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 6.6 MB/s  0:00:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----------------------- ---------------- 1.3/2.3 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 7.0 MB/s  0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("covidpolls.csv")

# %%
df['end_time'] = pd.to_datetime(df['end_date'])

# %%
rev_by_end_date = df.groupby('end_date')['disapprove'].mean()

# %%
rev_by_end_date.plot(
    kind='line',
    title="Trends In Disapproval Ratings of Biden and Trump's Covid19 Response"

# %%
# !jupyter nbconvert --to html --execute Untitled.ipynb
# Out:
# [NbConvertApp] Converting notebook Untitled.ipynb to html
# C:\Users\dirty\miniconda3\Lib\site-packages\zmq\_future.py:718: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# [NbConvertApp] Writing 271263 bytes to Untitled.html
